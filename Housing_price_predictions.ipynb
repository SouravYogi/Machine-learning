# %%
import pandas as pd

# %%
raw=pd.read_csv('E:/CS229/128_270_bundle_archive/kc_house_data.csv')

# %%
raw.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
raw.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
#Prices and Sq_living have a correlation of 0.7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8))
sns.regplot('sqft_living','price',data=raw,marker='+')

# %%
#Lets try to predict prices with Sq living

# %%
import numpy as np

# %%
y=np.array(raw['price'])

# %%
X=np.array([raw['sqft_living']]).reshape(21613,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,random_state=42)

# %%
lr=LinearRegression()

# %%
Xtrain,Xtest,ytrain,ytest=Xtrain.reshape(-1,1),Xtest.reshape(-1,1),ytrain.reshape(-1,1),ytest.reshape(-1,1)

# %%
lr.fit(Xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([[278.44089985]])

# %%
lr.intercept_
# Out:
# array([-39814.16265844])

# %%
lr.score(Xtest,ytest)
# Out:
# 0.4964768256677172

# %%
from sklearn.metrics import mean_squared_error

# %%
predictions=lr.predict(Xtest)

# %%
mean_squared_error(ytest,predictions)
# Out:
# 75320835437.85425

# %%
#Lets try to predict with two variables

# %%
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
X=np.array(raw[['sqft_living','grade']])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(raw['sqft_living'],raw['grade'],raw['price'],zdir='z')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y=np.array(raw['price'])

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,random_state=42)

# %%
lr.fit(Xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.score(Xtest,ytest)
# Out:
# 0.5403949362760566

# %%
#better score

# %%
#Lets add more features

# %%
predictions=lr.predict(Xtest)
mean_squared_error(ytest,predictions)
# Out:
# 68751229607.38011

# %%
X=np.array(raw[['sqft_living','grade','sqft_above','sqft_living15','bathrooms','']])
y=np.array(raw['price'])
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,random_state=42)

# %%
lr.fit(Xtrain,ytrain)
lr.score(Xtest,ytest)
# Out:
# 0.5505056035425475

# %%
predictions=lr.predict(Xtest)
mean_squared_error(ytest,predictions)
# Out:
# 67238798910.707344
